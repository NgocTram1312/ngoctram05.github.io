# %% [markdown]
# <a href="https://colab.research.google.com/github/NgocTram1312/ngoctram05.github.io/blob/gh-pages/Buoi03_%5BBT%5D_EDA_fin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas_datareader
# !pip install yfinance
# !pip install mplfinance
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 2.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import mplfinance as mpf
import seaborn as sns
import datetime as dt
# %matplotlib inline

# sửa lỗi tải dữ liệu của pandas_datareader
from IPython.display import display
import yfinance as yf

# %%
end = dt.datetime.now()
start = dt.datetime(2016, 1, 1)
print(f'{start} -> {end}')

# Use yfinance to fetch data
df = yf.download('AAPL', start=start, end=end)
# Out:
# 2016-01-01 00:00:00 -> 2025-10-23 11:03:05.082829
# [*********************100%***********************]  1 of 1 completed

# %%
display(df.head())
display(df.tail())
# Out:
# Price       Adj Close      Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2016-01-04  23.776184  26.337500  26.342501  25.500000  25.652500  270597600
# 2016-01-05  23.180368  25.677500  26.462500  25.602501  26.437500  223164000
# 2016-01-06  22.726730  25.174999  25.592501  24.967501  25.139999  273829600
# 2016-01-07  21.767565  24.112499  25.032499  24.107500  24.670000  324377600
# 2016-01-08  21.882660  24.240000  24.777500  24.190001  24.637501  283192000
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            AAPL        AAPL        AAPL        AAPL        AAPL
# Date
# 2025-10-16  247.449997  247.449997  249.039993  245.130005  248.250000
# 2025-10-17  252.289993  252.289993  253.380005  247.270004  248.020004
# 2025-10-20  262.239990  262.239990  264.380005  255.630005  255.889999
# ...

# %%
df.loc['2024-04-19']
# Out:
# Price      Ticker
# Adj Close  AAPL      1.638236e+02
# Close      AAPL      1.650000e+02
# High       AAPL      1.664000e+02
# Low        AAPL      1.640800e+02
# Open       AAPL      1.662100e+02
# Volume     AAPL      6.814940e+07
# Name: 2024-04-19 00:00:00, dtype: float64

# %%
df.to_csv('AAPL.csv')
df1 = pd.read_csv('AAPL.csv', index_col=0)

# %%
display(df1)
# Out:
#                      Adj Close               Close                High  \
# Price
# Ticker                    AAPL                AAPL                AAPL
# Date                       NaN                 NaN                 NaN
# 2016-01-04   23.77618408203125  26.337499618530273  26.342500686645508
# 2016-01-05  23.180368423461914  25.677499771118164  26.462499618530273
# 2016-01-06  22.726730346679688  25.174999237060547  25.592500686645508
# ...                        ...                 ...                 ...
# 2025-10-16   247.4499969482422   247.4499969482422   249.0399932861328
# 2025-10-17   252.2899932861328   252.2899932861328   253.3800048828125
# 2025-10-20    262.239990234375    262.239990234375   264.3800048828125
# 2025-10-21   262.7699890136719   262.7699890136719   265.2900085449219
# 2025-10-22  258.45001220703125  258.45001220703125   262.8500061035156
#
#                            Low                Open     Volume
# Price
# ...

# %%
df['Adj Close'].plot(legend=True, figsize=(12,8), title='AAPL', label = 'Adj Close')
# Out:
# <Axes: title={'center': 'AAPL'}, xlabel='Date'>

# %%
plt.figure(figsize=(12, 9))

top = plt.subplot2grid((12, 9), (0, 0), rowspan=10, colspan=9)
bottom = plt.subplot2grid((12, 9), (10, 0), rowspan=2, colspan=9)

top.plot(df.index, df['Adj Close'], color='blue')
bottom.plot(df.index, df['Volume'], color='red') # Changed to plot

top.axes.get_xaxis().set_visible(False)
top.set_title('AAPL')
top.set_ylabel('Adj Close')
bottom.set_ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %%
df.index
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#                '2016-01-14', '2016-01-15',
#                ...
#                '2025-10-09', '2025-10-10', '2025-10-13', '2025-10-14',
#                '2025-10-15', '2025-10-16', '2025-10-17', '2025-10-20',
#                '2025-10-21', '2025-10-22'],
#               dtype='datetime64[ns]', name='Date', length=2466, freq=None)
